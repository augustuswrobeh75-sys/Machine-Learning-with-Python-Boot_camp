# %% [markdown]
# <a href="https://colab.research.google.com/github/augustuswrobeh75-sys/Machine-Learning-with-Python-Boot_camp/blob/main/Python_Refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variable

# %%
# create a labeld storange backet and put a number inside
tomato_price = 150
pepper_price = 80
# Pull the value out of the baskets
print (tomato_price)
print (pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Change Tomato Price

# %%
tomato_price = 100
print (tomato_price)
# Out:
# 100

# %% [markdown]
# ML Anchor

# %%
#--- THE CLUES (Features grouped as X)---
rainfall_mm = 45.2    # clue 1
bags_avaliable = 100  # clue 2

#---  THE GOAL (Taget labeled as y) ---
predicted_price = 3200 # what our AI calculates

print("Inputs (X):", rainfall_mm, "mm rain,", bags_avaliable, "bags.")
print("output (y):", predicted_price, "LRD.")
# Out:
# Inputs (X): 45.2 mm rain, 100 bags.
# output (y): 3200 LRD.

# %% [markdown]
# Understanding Print

# %%
Liberia = 1847
print ("Liberia")
print (Liberia)
# Out:
# Liberia
# 1847

# %% [markdown]
# DATA TYPES

# %%
quantity = 50
price = 150.50
item_name = "tomatoes"
stall_is_open = True

print(type(quantity))   #
print(type (price))     #
print(type(item_name))  #
print(type (stall_is_open))    #
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
