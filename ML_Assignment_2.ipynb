# %% [markdown]
# <a href="https://colab.research.google.com/github/augustuswrobeh75-sys/Machine-Learning-with-Python-Boot_camp/blob/main/ML_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1: Type Conversion(The Nimba Truck Report)

# %%
transport_cost="750"

# The variable transport_cost was orginally stored as a string, the int() function is used to convert it into an integer.

transport_cost = int(transport_cost)

# Explicitly convert to an integer and add the car loader fee (250LRD)

total_delivery_cost=transport_cost+250
print(total_delivery_cost)



#part B: Output the clean report using an f-string

print(f"Ma christiana, your final shipping cost is:{total_delivery_cost} LRD.")
# Out:
# 1000
# Ma christiana, your final shipping cost is:1000 LRD.

# %% [markdown]
# Question 2: Lists & Matrices (Packing the Shipping crate)

# %% [markdown]
# A machine learning model works better with structured data instead of a loose flat list because the model expects information to be arranged in rows and columns like a table. A simple list only stores values in one line, but a matrix organizes the value into a proper structure that the AI system can process safely and correctly.

# %%
loose_stock= [45, 12, 88]
# Packing the loose stock list into a 2D matrix using double brackets
shipping_crate =[[45], [12], [88]]

print(shipping_crate)
# Out:
# [[45], [12], [88]]

# %% [markdown]
# Question 3: Dictionaries (Tuning the Motorbike Engine)

# %%
# Part A: Creating the python Dictionary for hyperparameters
yield_model_configs = {
    "egine_type": "Decision tree",
    "max_depth_layers": 15,
    "strict_mode": True
}

# Part B: Extracting the max depth constraint value using an f-string
print(f"System Check: Tuning engine depth to {yield_model_configs['max_depth_layers']} branches.")
# Out:
# System Check: Tuning engine depth to 15 branches.

# %% [markdown]
# Question 4:

# %%
import pandas as pd
gobachop_data = pd.DataFrame({
    "vendor": ["Ma Musu", "Sia", "Flomo"],
    "Sales": [4000, 9500, 1500]
    })

# Example of attributes: , shape tells us the size of the DataFrame
print("DataFrame shape:" , gobachop_data.shape)

# Example of method: .head() shows the first few rows
print(gobachop_data.head())


# Example of method: .describe() gives statistics for numeric columns
print(gobachop_data.describe())
# Out:
# DataFrame shape: (3, 2)
#     vendor  Sales
# 0  Ma Musu   4000
# 1      Sia   9500
# 2    Flomo   1500
#              Sales
# count     3.000000
# mean   5000.000000
# std    4092.676386
# min    1500.000000
# 25%    2750.000000
# 50%    4000.000000
# 75%    6750.000000
# max    9500.000000

# %%
print("it's mine")
# Out:
# it's mine
