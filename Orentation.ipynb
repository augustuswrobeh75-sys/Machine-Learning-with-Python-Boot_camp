# %% [markdown]
# <a href="https://colab.research.google.com/github/augustuswrobeh75-sys/Machine-Learning-with-Python-Boot_camp/blob/main/Orentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of a string

# %%
Greetings="what up, doctor"
print (Greetings)
# Out:
# what up, doctor

# %% [markdown]
# Example of Addition

# %%
A = 2
B = 3
C = A+B
print (C)
# Out:
# 5
