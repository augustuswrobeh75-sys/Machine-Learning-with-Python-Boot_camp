# %% [markdown]
# <a href="https://colab.research.google.com/github/augustuswrobeh75-sys/Machine-Learning-with-Python-Boot_camp/blob/main/Weekend_Assignment__1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Augustus L.B. Wrobeh Jr. 25,May 2026

# %% [markdown]
# Problem 1

# %%
# store 1847 in the variable
Liberia = 1847

# print the value stored in Liberia
print (Liberia)

#Print the word Liberia as text
print ("Liberia")

# Print(Liberia) prints the value stored in the variable, which is 1847
#print("Liberia") prints the actual text Liberia because it is inside quotes.
# Out:
# 1847
# Liberia

# %% [markdown]
# Problem 2

# %%
# store the country name in variable
country ="Liberia"

#Print the Variable value
print(country)

#print a sentence using the variable and number
print(country, "became independent in", 1847)
# Out:
# Liberia
# Liberia became independent in 1847

# %% [markdown]
# Problem 3

# %%
# print the sentence with double quotes around 1847
print('This year is "1847"')
# Out:
# This year is "1847"

# %% [markdown]
# Problem 4

# %%
# create variables
market_name="Sinkor big market"
total_market_table=200
price_per_bag=4200.50
is_market_open=True

#Print variables with labels
print("Market name:" , market_name)
print("Total market table:" , total_market_table)
print("Price per bag:" , price_per_bag)
print("Is market open" , is_market_open)


#Print Data types
print(type(market_name))
print(type(total_market_table))
print(type(price_per_bag))
print(type(is_market_open))
# Out:
# Market name: Sinkor big market
# Total market table: 200
# Price per bag: 4200.5
# Is market open True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# Problem 5
